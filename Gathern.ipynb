# %% [markdown]
# # Import Libraries

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns 
# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline 
# You can configure the format of the images: ‘png’, ‘retina’, ‘jpeg’, ‘svg’, ‘pdf’.
# %config InlineBackend.figure_format = 'png'

# %% [markdown]
# # Importing Libraries & Methods

# %%
from bs4 import BeautifulSoup
import requests

# %%
from bs4 import BeautifulSoup as bs

# %%
url = 'https://gathern.co/search/main/index?r' 

response = requests.get(url)

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.text[:1000]
# Out:
# '<!DOCTYPE html>\n<html lang="sa-ar" dir="rtl">\n<!--[if IE 8]> <html lang="sa-ar" class="ie8 no-js"> <![endif]-->\n<!--[if IE 9]> <html lang="sa-ar" class="ie9 no-js"> <![endif]-->\n<!--[if !IE]><!-->\n<head>\n    <meta charset="utf-8" />\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0"/>\n    <title>أفضل بيوت العطلات - Gathern | جاذر إن</title>\n    <meta name="robots" content="index,follow">\n    <link rel="canonical" href="https://gathern.co/search/main/index?r">\n    <meta name="theme-color" content="#5A409B" />\n    <link rel="manifest" href="/manifest.json" />\n    <meta name="keywords" content="شاليهات، منتجعات، مزارع، مخيمات، كرفانات، استراحات، فلل، شقق، شاليه، استراحة، منتجع، مخيم، مزرعة، فله، شقة، جاذر ان، gathern، اكتشف السعودية، العلا، ابها، الطائف، ">\n    <meta name="description" content="أفضل بيوت العطلات (شاليهات - منتجعات فندقية - مخيمات - شقق - مزارع) و بأسعار معقولة فى منصة جاذر '

# %%
page = response.text

# %% [markdown]
# # BeautifulSoup Basics

# %%
soup = BeautifulSoup(page, "lxml")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="rtl" lang="sa-ar">
# <!--[if IE 8]> <html lang="sa-ar" class="ie8 no-js"> <![endif]-->
# <!--[if IE 9]> <html lang="sa-ar" class="ie9 no-js"> <![endif]-->
# <!--[if !IE]><!-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
# <title>أفضل بيوت العطلات - Gathern | جاذر إن</title>
# <meta content="index,follow" name="robots"/>
# <link href="https://gathern.co/search/main/index?r" rel="canonical"/>
# <meta content="#5A409B" name="theme-color"/>
# <link href="/manifest.json" rel="manifest"/>
# <meta content="شاليهات، منتجعات، مزارع، مخيمات، كرفانات، استراحات، فلل، شقق، شاليه، استراحة، منتجع، مخيم، مزرعة، فله، شقة، جاذر ان، gathern، اكتشف السعودية، العلا، ابها، الطائف، " name="keywords"/>
# <meta content="أفضل بيوت العطلات (شاليهات - منتجعات فندقية - مخيمات - شقق - مزارع) و بأسعار معقولة فى منصة جاذر إن مرخصة و معتمدة من وزارة السياحة" name="description"/>
# <meta content="FNNrctot2BoD8o3t8kOtQFItp0IItS_wRU9gR7LmVzY" name="google-site-verification"/>
# <meta content="gU4G4gNc-9XQgc1zCxwyAEGYVvPZQMaSGevTJ1-Ia8c" name="google-site-verification"/>
# <meta content="eacc4a2929a3b75a" name="yandex-verification"/>
# <meta content="F5381F70BE40B0ACC55D79E8F4E8508D" name="msvalidate.01"/>
# <meta content="Gathern Holding" name="author"/>
# <meta content="أفضل بيوت العطلات - Gathern | جاذر إن" property="og:title"/>
# <meta content="أفضل بيوت العطلات - Gathern | جاذر إن" name="twitter:title"/>
# <meta content="https://gathern.co/search" property="og:url"/>
# <meta content="أفضل بيوت العطلات - Gathern | جاذر إن" name="twitter:card"/>
# <meta content="Gathern Holding" name="twitter:site"/>
# <meta content="أفضل بيوت العطلات (شاليهات - منتجعات فندقية - مخيمات - شقق - مزارع) و بأسعار معقولة فى منصة جاذر إن مرخصة و معتمدة من وزارة السياحة" name="twitter:description"/>
# <meta content="أفضل بيوت العطلات (شاليهات - منتجعات فندقية - مخيمات - شقق - مزارع) و بأسعار معقولة فى منصة جاذر إن مرخصة و معتمدة من وزارة السياحة" property="og:description"/>
# <meta content="https://gathern.co/img/default-share-image.png" name="twitter:image"/>
# <meta content="https://gathern.co/img/default-share-image.png" property="og:image"/>
# <meta content="en_GB" property="og:locale"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/assets/eb1f3e3f/css/bootstrap.min-rtl.css?v=1617006873" rel="stylesheet"/>
# <link href="/css/collections.min.css?v=1617006873" rel="stylesheet"/>
# <link href="/css/app-rtl.css?v=1636974751" rel="stylesheet"/>
# <link href="/css/theme-chalk.css" rel="stylesheet"/>
# <link href="/css/advanced-search.css?ref=24032021" rel="stylesheet"/>
# <script>var scParams = "";</script> <meta content="_csrf" name="csrf-param"/>
# <meta content="oH7m-qh14fRuCaQLBcS20xz13ZPIfvuVWN_qPsn26t3iLLnL_BePoQBT035Kro6iMYK45oNGgdwPiJxakLCejA==" name="csrf-token"/>
# </head>
# <body class="animated">
# <div class="container-fluid no-padding">
# <header class="header">
# <div class="top-menu">
# <div class="container">
# <div class="row">
# <div class="col-8 col-md-2 col-lg-2 logo">
# <a href="/" title=""><img alt="جاذر إن" src="/img/Group1@2x.png"/></a>
# </div>
# <div class="col-2 col-md-7 col-lg-7 navMenu position-relative">
# <nav class="navbar navbar-expand-md navbar-dark">
# <button class="navbar-toggler" type="button">
# <i class="fas fa-bars"></i>
# </button>
# <div class="collapse navbar-collapse">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="nav-link" href="/">الرئيسية</a>
# </li>
# <li>
# <a class="nav-link" href="/chalets/all"> شاليهات و استراحات</a>
# </li>
# <li>
# <a class="nav-link" href="/camps/all"> مخيمات</a>
# </li>
# <li>
# <a class="nav-link" href="/farms/all">مزارع</a>
# </li>
# <li>
# <a class="nav-link" href="/apartments/all">فلل وشقق</a>
# </li>
# <li>
# <a class="nav-link" href="/special">العروض</a>
# </li>
# </ul>
# </div>
# </nav>
# <div class="navbarMenu animated fadeInLeft faster">
# <i class="fas fa-times cnavbarMenu"></i>
# <ul class="navbarMenuItems mr-auto">
# <li>
# <a href="/">الرئيسية</a>
# </li>
# <li>
# <a href="#" rel="nofollow">
#                                         التصنيفات                                    </a>
# <ul class="navbarMenuItemsSub">
# <li><a href="/chalets/all"><i class="fas fa-circle"></i> شاليهات و استراحات</a></li>
# <li><a href="/camps/all"> <i class="fas fa-circle"></i> مخيمات</a></li>
# <li><a href="/farms/all"> <i class="fas fa-circle"></i>مزارع</a></li>
# <li><a href="/apartments/all"> <i class="fas fa-circle"></i>فلل وشقق</a></li>
# <li><a href="/special"> <i class="fas fa-circle"></i>العروض</a></li>
# </ul>
# </li>
# <li>
# <a href="/contact-us" rel="nofollow">اتصل بنا</a>
# </li>
# </ul>
# <div class="mobConChooseLNG">
# <a alt="sa-en" class="btn signupLogin mColor" href="https://gathern.co/site/lang?lang=sa-en" rel="nofollow" title="sa-en"><img alt="English" data-src="/img/gb.png"/><br/>English</a>
# </div>
# </div>
# </div>
# <div class="col-2 col-md-3 col-lg-3 top-login">
# <a class="btn signupLogin" href="https://gathern.co/join">
# <i class="far fa-user"></i> <span>تسجيل / دخول</span>
# </a>
# <div class="ConChooseLNG">
# <a class="btn signupLogin" href="https://gathern.co/site/lang?lang=sa-en" rel="nofollow"><img alt="English" data-src="/img/gb.png"/> English</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="GnBreadcrumb" itemprop="breadcrumb">
# <div class="container">
# <ol class="breadcrumb"><li><a href="https://gathern.co">الرئيسية</a><i class="fas fa-chevron-left"></i></li><li class="active">نتائج البحث</li>
# </ol> </div>
# </div>
# </header>
# <main>
# <div :class="{'searchApp--searchview': searchView}" id="searchApp">
# <template v-if="search_meta">
# <div class="topSerachBar" v-if="! loading">
# <div class="container">
# <div class="row">
# <template v-if="!isMobile">
# <div class="col-4 col-md-4 col-lg-4">
# <div class="form-group">
# <label>المدينة</label>
# <div class="form-group-icon select-group">
# <el-select :filterable="true" number="" placeholder="كل المدن" v-model.number="search_params.city">
# <el-option :key="city.id" :label="city.name" :value="city.id" v-for="city in cities">
# </el-option>
# </el-select>
# </div>
# </div>
# </div>
# <div class="col-4 col-md-4 col-lg-4">
# <div class="form-group">
# <label>الفئات</label>
# <div class="form-group-icon select-group">
# <el-select :filterable="true" multiple="" number="" placeholder="كل الفئات" v-model="search_params.unit_cats">
# <el-option :key="amenity" :label="amenity" :value="amenity" v-for="(amenity, key) in search_meta.unit_cats">
# </el-option>
# </el-select>
# </div>
# </div>
# </div>
# <div class="col-4 col-md-4 col-lg-4">
# <div class="form-group">
# <label>تاريخ الحجز</label>
# <div class="form-group-icon select-group">
# <el-date-picker :clearable="false" :editable="false" :picker-options="{disabledDate:checkdatisdisabled, onPick:dateChangeCheckInCheckOut}" end-placeholder="تاريخ المغادرة" format="yyyy/MM/dd" placeholder="موعد الحجز" range-separator="الى" start-placeholder="تاريخ المناسبة" type="datetimerange" v-model="search_params.checkin_checkout" value-format="yyyy-MM-dd">
# </el-date-picker>
# <el-input type="hidden" v-model="search_params.check_in"></el-input>
# <el-input type="hidden" v-model="search_params.check_out"></el-input>
# </div>
# </div>
# </div>
# </template>
# </div>
# </div>
# </div>
# </template>
# <div class="container">
# <div class="row">
# <template v-if="isMobile">
# <div :class="{'searchApp__resultspanel--inactive': searchView}" class="mainInputAdvancedSerach" v-if="! loading">
# <div class="advancedFilOrde">
# <div class="row">
# <div class="col-6">
# <div id="filter-button">
# <a class="btn-filter-button" href="">
# <i class="fas fa-filter"></i> فلتر                                    </a>
# </div>
# </div>
# <div class="col-6">
# <div class="advacedFilDrop">
# <button class="btn" id="sortBy" ref="button" type="button">
# <i class="fas fa-sort"></i> ترتيب                                    </button>
# </div>
# </div>
# </div>
# </div>
# <ul aria-labelledby="sortBy" class="advacedFilDropList" v-closable="{exclude: ['button'],handler: 'closeFilterOutSide' }" v-if="displayFilterDrop">
# <li>
# <a :class="{'advacedFilDropActive': isorderactive('rand')}" href="#">
# <span class="el-radio__inner"></span> الكل                            </a>
# </li>
# <li>
# <a :class="{'advacedFilDropActive': isorderactive('rating')}" href="#">
# <span class="el-radio__inner"></span> الأعلى تقييماً                            </a>
# </li>
# <li>
# <a :class="{'advacedFilDropActive': isorderactive('nearest')}" href="#">
# <span class="el-radio__inner"></span> الأقرب لموقعى                            </a>
# </li>
# <li>
# <a :class="{'advacedFilDropActive': isorderactive('views_highest')}" href="#">
# <span class="el-radio__inner"></span> الأعلى مشاهدة                            </a>
# </li>
# <li>
# <a :class="{'advacedFilDropActive': isorderactive('price_lowest')}" href="#">
# <span class="el-radio__inner"></span> الأقل سعراً                            </a>
# </li>
# <li>
# <a :class="{'advacedFilDropActive': isorderactive('price_highest')}" href="#">
# <span class="el-radio__inner"></span>  الأعلى سعراً                            </a>
# </li>
# </ul>
# </div>
# </template>
# <div :class="{'searchApp__filterpanel--active': searchView}" class="col-12 col-md-4 col-lg-4 searchApp__filterpanel">
# <template v-if="isMobile">
# <i class="closeFilter fas fa-times"></i>
# <button class="btn btn-reset">اعادة تعيين</button>
# </template>
# <template v-if="search_meta">
# <div class="accordion" id="advancedSBoxAccordion">
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-1" data-toggle="collapse">
# <h1><span class="fas fa-search"></span> البحث المتقدم</h1>
# <i class="fas fa-chevron-up"></i>
# </div>
# <div class="advancedCont collapse show" id="advancedSBox-1">
# <template v-if="isMobile">
# <div class="form-group">
# <label>المدينة</label>
# <div class="form-group-icon select-group">
# <el-select :filterable="true" number="" placeholder="كل المدن" v-model.number="search_params.city">
# <el-option :key="city.id" :label="city.name" :value="city.id" v-for="city in cities">
# </el-option>
# </el-select>
# </div>
# </div>
# <div class="form-group">
# <div class="row">
# <div class="col-6 col-md-6 col-lg-6">
# <label>اسم العقار</label>
# <div class="form-group-icon select-group">
# <el-input :clearable="true" debounce="800" placeholder="اسم العقار" v-model="search_params.query" v-on:changes="handleinputChange"></el-input>
# </div>
# </div>
# <div class="col-6 col-md-6 col-lg-6">
# <label>رمز الوحدة</label>
# <div class="form-group-icon select-group">
# <el-input placeholder="رمز الوحدة" type="tel" v-model="search_params.unit_code"></el-input>
# </div>
# </div>
# </div>
# </div>
# <div class="form-group">
# <div class="row">
# <div class="col-6 col-md-6 col-lg-6">
# <label>اسم الحي</label>
# <div class="form-group-icon select-group">
# <el-select :filterable="true" :multiple="true" number="" placeholder="الحى" v-model="search_params.areas">
# <el-option :key="area.id" :label="area.name" :value="area.id" v-for="area in allselectedCityAreas">
# </el-option>
# </el-select>
# </div>
# </div>
# <div class="col-6 col-md-6 col-lg-6">
# <label>الاتجاهات</label>
# <div class="form-group-icon select-group">
# <el-select :filterable="true" placeholder="اختر الأتجاه" v-model="search_params.direction">
# <el-option :key="key" :label="dir" :value="key" v-for="(dir , key) in dirs">
# </el-option>
# </el-select>
# </div>
# </div>
# </div>
# </div>
# </template>
# <template v-else="">
# <div class="form-group">
# <label>اسم العقار</label>
# <div class="form-group-icon select-group">
# <el-input :clearable="true" debounce="800" placeholder="اسم العقار" v-model="search_params.query" v-on:changes="handleinputChange"></el-input>
# </div>
# </div>
# <div class="form-group">
# <label>اسم الحي</label>
# <div class="form-group-icon select-group">
# <el-select :filterable="true" :multiple="true" number="" placeholder="الحى" v-model="search_params.areas">
# <el-option :key="area.id" :label="area.name" :value="area.id" v-for="area in allselectedCityAreas">
# </el-option>
# </el-select>
# </div>
# </div>
# <div class="form-group">
# <div class="row">
# <div class="col-6 col-md-6 col-lg-6">
# <label>الاتجاهات</label>
# <div class="form-group-icon select-group">
# <el-select :filterable="true" placeholder="اختر الأتجاه" v-model="search_params.direction">
# <el-option :key="key" :label="dir" :value="key" v-for="(dir , key) in dirs">
# </el-option>
# </el-select>
# </div>
# </div>
# <div class="col-6 col-md-6 col-lg-6">
# <label>رمز الوحدة</label>
# <div class="form-group-icon select-group">
# <el-input placeholder="رمز الوحدة" type="number" v-model="search_params.unit_code"></el-input>
# </div>
# </div>
# </div>
# </div>
# </template>
# </div>
# </div>
# <template v-if="unit_label_counts(search_meta.labels) &gt; 0">
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-12" data-toggle="collapse">
# <h4><span class="fas fa-tags"></span> اختيار جاذر إن</h4>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse show" id="advancedSBox-12">
# <el-checkbox-group v-model="search_params.labels">
# <template v-for="(label, key, index) in search_meta.labels">
# <el-checkbox :label="label.id"><b>{{ label.value }}</b><p>{{ label.description }}</p></el-checkbox>
# </template>
# </el-checkbox-group>
# </div>
# </div>
# </template>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-2" data-toggle="collapse">
# <h4><span class="fas fa-search-dollar"></span> السعر</h4>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-2">
# <div class="form-group sliderRange">
# <template>
# <vue-slider :drag-end="stopDropPrice = true" :interval="100" :lazy="true" :max="10000" :min="0" :tooltip="'always'" :tooltipplacement="'top'" ref="slider" v-model="search_params.prices_units"></vue-slider>
# </template>
# </div>
# </div>
# </div>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-3" data-toggle="collapse">
# <h2><span class="fas fa-store-alt"></span> نوع العقار</h2>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-3">
# <el-checkbox-group v-model="search_params.chalet_cats">
# <template v-for="(cat, key, index) in search_meta.chalet_cats">
# <el-checkbox :label="cat"></el-checkbox>
# </template>
# </el-checkbox-group>
# </div>
# </div>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-4" data-toggle="collapse">
# <h4><span class="fas fa-restroom"></span> السعة</h4>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-4">
# <el-checkbox-group v-model="search_params.capacity_units">
# <template v-for="(capacity, key, index) in search_meta.capacity_units">
# <el-checkbox :label="capacity"></el-checkbox>
# </template>
# </el-checkbox-group>
# </div>
# </div>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-9" data-toggle="collapse">
# <h4><span class="fas fa-bed"></span> غرف النوم و الأسرّة</h4>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-9">
# <div class="row">
# <template>
# <div class="col-4 col-lg-4">
# <span>عدد الغرف</span>
# </div>
# <div class="col-8 col-lg-8">
# <el-input-number :max="10" :min="0" class="plusMinJsInput" v-model="search_params.total_rooms"></el-input-number>
# <span class="defaultValInputPr">-</span>
# </div>
# </template>
# <template>
# <div class="col-4 col-lg-4">
# <span>سرير مفرد</span>
# </div>
# <div class="col-8 col-lg-8">
# <el-input-number :max="10" :min="0" class="plusMinJsInput" v-model="search_params.total_single_beds"></el-input-number>
# <span class="defaultValInputPs">-</span>
# </div>
# </template>
# <template>
# <div class="col-4 col-lg-4">
# <span>سرير ماستر</span>
# </div>
# <div class="col-8 col-lg-8">
# <el-input-number :max="10" :min="0" class="plusMinJsInput" v-model="search_params.total_master_beds"></el-input-number>
# <span class="defaultValInputPm">-</span>
# </div>
# </template>
# </div>
# </div>
# </div>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-5" data-toggle="collapse">
# <h4><span class="far fa-star"></span> التقييم</h4>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-5">
# <el-checkbox-group v-model="search_params.unit_reviews">
# <template v-for="(review, key, index) in search_meta.unit_reviews">
# <el-checkbox :label="review"></el-checkbox>
# </template>
# </el-checkbox-group>
# </div>
# </div>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-50" data-toggle="collapse">
# <h4><span class="far fa-star"></span> الفئات</h4>
# <i class="fas fa-venus-double"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-50">
# <el-checkbox-group v-model="search_params.unit_cats">
# <template v-for="(cat, key, index) in search_meta.unit_cats">
# <el-checkbox :label="cat"></el-checkbox>
# </template>
# </el-checkbox-group>
# </div>
# </div>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-6" data-toggle="collapse">
# <h4><span class="fas fa-swimming-pool"></span> المسبح</h4>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-6">
# <el-checkbox-group v-model="search_params.pool_types">
# <template v-for="(type, key, index) in search_meta.pool_types">
# <el-checkbox :label="type" v-model="search_params.pool_types"></el-checkbox>
# </template>
# </el-checkbox-group>
# </div>
# </div>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-7" data-toggle="collapse">
# <h4><span class="fas fa-wifi"></span> المرافق</h4>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-7">
# <el-checkbox-group v-model="search_params.amenities">
# <template v-for="(amenity, key, index) in search_meta.amenities">
# <el-checkbox :label="amenity"></el-checkbox>
# </template>
# </el-checkbox-group>
# </div>
# </div>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-10" data-toggle="collapse">
# <h4><span class="fas fa-utensils"></span> مرافق المطبخ</h4>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-10">
# <el-checkbox-group v-model="search_params.kitchen_amenities">
# <template v-for="(amenity, key, index) in search_meta.kitchen_amenities">
# <el-checkbox :label="amenity"></el-checkbox>
# </template>
# </el-checkbox-group>
# </div>
# </div>
# <div class="advancedSBox">
# <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-11" data-toggle="collapse">
# <h4><span class="fas fa-bath"></span> مرافق دورات المياه</h4>
# <i class="fas fa-chevron-down"></i>
# </div>
# <div class="advancedCont collapse" id="advancedSBox-11">
# <el-checkbox-group v-model="search_params.toilet_amenities">
# <template v-for="(amenity, key, index) in search_meta.toilet_amenities">
# <el-checkbox :label="amenity"></el-checkbox>
# </template>
# </el-checkbox-group>
# </div>
# </div>
# </div>
# </template>
# <template v-if="isMobile">
# <div class="advancedTotalResultBox">
# <div class="row">
# <div class="col-6">
# <template v-if="total_count &gt;= 300">
# <span class="totalResultCount">+300 مكان الإقامة</span>
# </template>
# <template v-else="">
# <span class="totalResultCount">({{ total_count }}) مكان الإقامة</span>
# </template>
# </div>
# <div class="col-6">
# <el-button :disabled="total_count &lt; 1" :loading="loading" class="mainFilterSearchBtn" type="primary">
# <i :loading="loading"></i>
#                                     اظهر النتائج                                </el-button>
# </div>
# </div>
# </div>
# </template>
# </div>
# <div :class="{'searchApp__resultspanel--inactive': searchView}" class="col-12 col-md-8 col-lg-8 pr-0 searchApp__resultspanel fresult" id="mainresultscontainer">
# <div class="main-content">
# <template v-if="!isMobile">
# <ul :class="{'searchApp__filterpanel--active': searchView}" class="advancedFilter" v-if="search_meta">
# <li class="Filterer__list__item">
# <a :class="{'Filterer__button--is-active': isorderactive('rand')}" class="Filterer__button" href="#">
#                                     الكل                                </a>
# </li>
# <li class="Filterer__list__item">
# <a :class="{'Filterer__button--is-active': isorderactive('rating')}" class="Filterer__button" href="#">
#                                     الأعلى تقييماً                                </a>
# </li>
# <li class="Filterer__list__item">
# <a :class="{'Filterer__button--is-active': isorderactive('nearest')}" class="Filterer__button" href="#">
#                                     الأقرب لموقعى                                </a>
# </li>
# <li class="Filterer__list__item">
# <a :class="{'Filterer__button--is-active': isorderactive('views_highest')}" class="Filterer__button" href="#">
#                                     الأعلى مشاهدة                                </a>
# </li>
# <li class="Filterer__list__item">
# <a :class="{'Filterer__button--is-active': isorderactive('price_lowest')}" class="Filterer__button" href="#">
#                                     الأقل سعراً                                </a>
# </li>
# <li class="Filterer__list__item">
# <a :class="{'Filterer__button--is-active': isorderactive('price_highest')}" class="Filterer__button" href="#">
#                                     الأعلى سعراً                                </a>
# </li>
# </ul>
# </template>
# <template v-if="loading">
# <content-placeholder :rows="placeholderRows" class="content-placeholder"></content-placeholder>
# </template>
# <div class="items-lists" v-if="! loading">
# <template v-for="unitAds in total_results_ads">
# <div :data-id="unitAds.unit_id" class="ChaletItemBox ChaletItemBox--unit" v-bind:class="{ bgAdvColor: unitAds.is_ads}" v-view.once="viewHandler">
# <div class="ChaletItemBox__thumb">
# <div class="ChaletItemContSlider">
# <div class="ChaletItemBoxSlider owl-carousel owl-theme">
# <a :href="unit_view_link(unitAds)" :title="unitAds.title" class="ChaletItemLinkAds" target="_blank" v-for="unit_mage in unit_cover(unitAds)">
# <div class="slideImg">
# <img :alt="unitAds.title" :data-src="unit_mage" class="img-responsive owl-lazy"/>
# </div>
# </a>
# </div>
# </div>
# <div class="ChaletItemBox_view">
# <i class="fa fa-eye"></i>
#                 {{ unitAds.views_count_k }}
#             </div>
# <template v-if="unitAds.isUnitAvailable == false">
# <div class="notAvialbelUnitDate">
# <span>محجوز فى هذا التاريخ</span>
# </div>
# </template>
# <template v-if="unitAds.is_ads">
# <label class="adsChaletLabel">إعلان</label>
# </template>
# </div>
# <div class="ChaletItemBox__content">
# <div class="row padd18">
# <div class="col-md-7 col-xs-9">
# <h3 class="ChaletItemBox__content__name__ads">
# <a :href="unit_view_link(unitAds)" :title="unitAds.title" target="_blank">
#                             {{ unitAds.chalet_title }}<br/>
# <span>{{ unitAds.title }}</span>
# </a>
# </h3>
# <div class="col-md-12 col-xs-12 pr-0 rateNewCont"><i class="fa fa-star starColor"></i> <b>{{ unitAds.total_present }}</b> ({{ unitAds.total_reviews }}) تقييم</div>
# <div class="col-md-12 col-xs-12 pr-0">
# <p class="ChaletItemBoxLocation">
# <i class="fa fa-map-marker"></i>
# <span>{{ unitAds.address.city }}</span>,
#                             <span>{{ unitAds.address.area }}</span>
# </p>
# </div>
# <div class="col-md-12 col-xs-12 pr-0">
# <template v-if="unitAds.booking_count &gt; 0">
# <div class="ChaletItemBookingCount">
#                                 تم حجزه {{ unitAds.booking_count }} مرات هذا الاسبوع                            </div>
# </template>
# </div>
# </div>
# <div class="col-md-5 col-xs-3 priceLineRight">
# <div class="contPRicing">
# <template v-if="unitAds.label">
# <div class="label">
# <span :style="{'background-color':unitAds.label['color']}">
#                                 {{ unitAds.label['label'] }}
#                                 </span>
# </div>
# </template>
# <div class="ChaletItemPrice">
# <template v-if="unitAds.has_cancel_price">
# <div class="ChaletItemPrice__Old">
# <b>{{ unitAds.cancel_price_format }}</b>
#                                     ر.س                                </div>
# </template>
# <div class="ChaletItemPrice__New">
# <b>{{ unitAds.avg_price_format }}</b>
#                                 ر.س                                <span class="nightsSlashSpan no-padding">/</span>
# <span class="nightsSpan">{{ unitAds.day_flag }}</span>
# <el-popover placement="top" title="تفاصيل السعر" v-model="tipVisibles[unitAds.id]" width="240">
# <span class="closePopServ">X</span>
# <div class="row servicesPriceCont">
# <div class="col-7 col-md-7">{{ unitAds.day_price_format }} x <span class="unicode-bidi">{{ unitAds.nights }} <template v-if="unitAds.nights &gt; 1">ليالى</template><template v-else="">ليلة</template></span></div>
# <div class="col-5 col-md-5">{{ unitAds.price_before_discount }} ر.س</div>
# <template v-for="service in unitAds.services">
# <div class="col-7 col-md-7" style="font-size: 11px;" v-bind:class="{ servDiscountTitle:  service.id == 0}">{{ service.title }}</div>
# <div class="col-5 col-md-5" v-bind:class="{ servDiscountAmount:  service.id == 0}">{{ service.amount_value }} ر.س</div>
# </template>
# </div>
# <span class="servicesPrice" slot="reference">{{ unitAds.final_price_services }} ر.س القيمة الإجمالية</span>
# </el-popover>
# </div>
# </div>
# </div>
# <div class="text-center">
# <a :href="unit_view_link(unitAds)" class="btn btnViewUnitSearch" target="_blank">تفاصيل</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </template>
# <template v-if="! loading">
# <div class="alert alert-warning" role="alert" v-if="! hasResults">
#                                 لم يتم العثور على نتائج توافق بحثك                            </div>
# </template>
# <template v-for="unit in total_results">
# <div :class="{ 'widgetBusyUnit' : unit.isUnitAvailable == false}" :data-id="unit.unit_id" class="ChaletItemBox ChaletItemBox--unit" v-view="viewUnitsHandler" v-view.once="viewHandler">
# <div class="ChaletItemBox__thumb">
# <div class="ChaletItemContSlider">
# <div class="ChaletItemBoxSlider owl-carousel owl-theme">
# <a :href="unit_view_link(unit)" :title="unit.title" class="ChaletItemLinkAds" target="_blank" v-for="unit_mage in unit_cover(unit)">
# <div class="slideImg">
# <img :alt="unit.title" :data-src="unit_mage" class="img-responsive owl-lazy"/>
# </div>
# </a>
# </div>
# </div>
# <div class="ChaletItemBox_view">
# <i class="fa fa-eye"></i>
#                 {{ unit.views_count_k }}
#             </div>
# <template v-if="unit.isUnitAvailable == false">
# <div class="notAvialbelUnitDate">
# <span>محجوز فى هذا التاريخ</span>
# </div>
# </template>
# </div>
# <div class="ChaletItemBox__content">
# <div class="row padd18">
# <div class="col-md-7 col-9">
# <h3>
# <a :href="unit_view_link(unit)" :title="unit.title" target="_blank">
#                             {{ unit.chalet_title }}<br/>
# <span>{{ unit.title }}</span>
# </a>
# </h3>
# <div class="col-md-12 col-12 pr-0 rateNewCont"><i class="fa fa-star starColor"></i> <b>{{ unit.total_present }}</b> ({{ unit.total_reviews }}) تقييم</div>
# <div class="col-md-12 col-12 pr-0">
# <p class="ChaletItemBoxLocation">
# <i class="fa fa-map-marker"></i>
# <span>{{ unit.address.city }}</span>,
#                             <span>{{ unit.address.area }}</span>
# </p>
# </div>
# <div class="col-md-12 col-12 pr-0">
# <template v-if="unit.booking_count &gt; 0">
# <div class="ChaletItemBookingCount">
#                                 تم حجزه {{ unit.booking_count }} مرات هذا الاسبوع                            </div>
# </template>
# </div>
# </div>
# <div class="col-md-5 col-3 priceLineRight">
# <template v-if="unit.label">
# <div class="label">
# <span :style="{'background-color':unit.label['color']}">
#                             {{ unit.label['label'] }}
#                             </span>
# </div>
# </template>
# <div class="contPRicing">
# <div class="ChaletItemPrice">
# <template v-if="unit.has_cancel_price">
# <div class="ChaletItemPrice__Old">
# <b>{{ unit.cancel_price_format }}</b>
#                                     ر.س                                </div>
# </template>
# <div class="ChaletItemPrice__New">
# <b>{{ unit.avg_price_format }}</b>
#                                 ر.س                                <span class="nightsSlashSpan no-padding">/</span>
# <span class="nightsSpan">
#                                     {{ unit.day_flag }}
#                                 </span>
# <el-popover placement="top" title="تفاصيل السعر" v-model="tipVisibles[unit.id]" width="240">
# <span class="closePopServ">X</span>
# <div class="row servicesPriceCont">
# <div class="col-7 col-md-7">{{ unit.day_price_format }} x <span class="unicode-bidi">{{ unit.nights }}<template v-if="unit.nights &gt; 1">ليالى</template><template v-else="">ليلة</template></span>
# </div>
# <div class="col-5 col-md-5">{{ unit.price_before_discount }} ر.س</div>
# <template v-for="service in unit.services">
# <div class="col-7 col-md-7" style="font-size: 11px;" v-bind:class="{ servDiscountTitle:  service.id == 0}">{{ service.title }}</div>
# <div class="col-5 col-md-5" v-bind:class="{ servDiscountAmount:  service.id == 0}">{{ service.amount_value }} ر.س</div>
# </template>
# </div>
# <span class="servicesPrice" slot="reference">{{ unit.final_price_services }} ر.س القيمة الإجمالية</span>
# </el-popover>
# </div>
# </div>
# </div>
# <div class="text-center">
# <a :href="unit_view_link(unit)" class="btn btnViewUnitSearch" style="bottom: 0" target="_blank">تفاصيل</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </template>
# </div><!-- ./items-lists-->
# <!-- pagination -->
# <el-pagination :current-page="search_params.page" :total="total_count" background="" layout="prev, pager, next" v-on:current-change="handle_pagination">
# </el-pagination>
# </div><!-- ./main-content-->
# </div>
# </div>
# <div class="row" id="tags_links">
# <div class="col-12" style="margin: 10px 0px 20px 0px;">
# <template v-for="searchTag in total_search_tags" v-if="!loading &amp;&amp; total_search_tags.length">
# <a :href="searchTag.url" :title="searchTag.title" style="float: right;margin-left: 10px;margin-bottom: 10px;border: 1px solid #e0e0e0;border-radius: 5px;padding: 10px;color: #838499;" target="_blank">
# <i class="fas fa-circle" style="color: #fdcd05;"></i>
#     {{ searchTag.subtitle }}
# </a>
# </template>
# </div>
# </div>
# </div>
# </div>
# </main>
# <footer>
# <div class="container">
# <div class="row">
# <div class="col-12 col-md-4 col-lg-4">
# <div class="foolgo">
# <a href="/"><img alt="جاذر إن" class="img-responsive" data-src="/img/Group1@2x.png"/></a>
# </div>
# <div class="foosup">
# <div class="foosupimg"><img alt="خدمة العملاء" class="img-responsive" data-src="/img/operator-27@2x.png"/> </div>
# <div class="foosupcon">
# <p>خدمة العملاء</p>
# <p><a href="tel:920007858">920007858</a></p>
# <p>9:30 am - 12:00 am</p>
# </div>
# </div>
# </div>
# <div class="col-6 col-md-4 col-lg-4 fooLinksCol">
# <h3 class="fooHeadline">روابط سريعة</h3>
# <ul class="fooLinks">
# <li><a href="/" title="">الرئيسية</a></li>
# <li><a href="/page/terms" rel="nofollow" title="">شروط الإستخدام</a></li>
# <li><a href="/faqs/customer" rel="nofollow" title="">الاسئلة المتكررة</a></li>
# <li><a href="/special" title="">العروض</a></li>
# <li><a href="/contact-us" rel="nofollow" title="">اتصل بنا</a></li>
# </ul>
# </div>
# <div class="col-12 col-md-4 col-lg-4">
# <h3 class="fooHeadline hideInMobile">جاذر إن  على السوشيال ميديا</h3>
# <ul class="fooLinksSoc">
# <li><a href="https://www.youtube.com/channel/UCHj6Azkw15xvh_Fs6KwiRDA" rel="noopener" target="_blank" title="youtube"><img alt="youtube" class="img-responsive" data-src="/img/youtube-44.png"/></a></li>
# <li><a href="https://www.instagram.com/gathernApp/" rel="noopener" target="_blank" title="instagram"><img alt="instagram" class="img-responsive" data-src="/img/instagram-41.png"/></a></li>
# <li><a href="https://www.facebook.com/gather.n1/" rel="noopener" target="_blank" title="facebook"><img alt="facebook" class="img-responsive" data-src="/img/facebook-41.png"/></a></li>
# <li><a href="https://twitter.com/gathernApp" rel="noopener" target="_blank" title="twitter"><img alt="twitter" class="img-responsive" data-src="/img/twitter-42.png"/></a></li>
# <li><a href="#" rel="noopener" target="_blank" title="snapchat"><img alt="snapchat" class="img-responsive" data-src="/img/snapchat-23.png"/></a></li>
# </ul>
# <p class="fooCopyRight">جميع الحقوق محفوظة © 2016 - 2021 جاذر إن</p>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <div class="modal fade modal-fullscreen" id="panorama-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <h4 class="modal-title d-none" id="">صور بانورامية</h4>
# <button aria-label="Close" class="close" data-dismiss="modal" type="button">
# <i class="far fa-window-close"></i>
# </button>
# </div>
# <div class="modal-body">
# <div id="lightbox-panorama"></div>
# </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="modalLabel" class="modal fade" id="GNModalUp" role="dialog" style="    z-index: 10051;" tabindex="-1">
# <div class="modal-dialog" role="document" style="width: 400px;left: 17px;">
# <div class="modal-content">
# <div class="modal-body">
#                 ...
#             </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="modalLabel" class="modal fade" id="GNModal" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-body">
#                 ...
#             </div>
# </div>
# </div>
# </div>
# <div aria-hidden="true" aria-labelledby="modalLabel" class="modal fade" id="GNModalBig" role="dialog">
# <div class="modal-dialog" role="document" style="width: 900px;">
# <div class="modal-content">
# <div class="modal-body">
#                 ...
#             </div>
# </div>
# </div>
# </div>
# <script>
#     checkinVar = "2021-11-23";
#     logoUrl = "https://gathern.co/images/logo.png";
#     webSocketUrl = "wss://gathern.co/webscoket";
#     csrfToken = "oH7m-qh14fRuCaQLBcS20xz13ZPIfvuVWN_qPsn26t3iLLnL_BePoQBT035Kro6iMYK45oNGgdwPiJxakLCejA==";
#     checkInDate = "2021-11-23";
#     checkOutDate = "2021-11-24";
#     GN_lang = "ar";
# </script>
# <script src="/assets/2587954e/jquery.js?v=1490036520"></script>
# <script src="/assets/eb1f3e3f/js/bootstrap.bundle.min.js?v=1597486042"></script>
# <!--[if lt IE 9]>
# <script src="/assets/bf4b8ce/dist/html5shiv.min.js?v=1437422640"></script>
# <![endif]-->
# <script data-auto-replace-svg="nest" src="/plugins/fontawesome/js/all.min.js?v=1597486042"></script>
# <script src="/js/collectionsCustom.min.js?v=1616674119"></script>
# <script src="/js/firebase.min.js?v=1612956581"></script>
# <script src="/js/app.js?v=1622720590"></script>
# <script src="/js/advanced-search.js?ref=24032021"></script>
# <script>
#      window.addEventListener("load", function(){
#
#          if (navigator.geolocation && localStorage.getItem('lat') == null) {
#             navigator.geolocation.getCurrentPosition(
#                 function(position) {
#                     localStorage.setItem("lat", position.coords.latitude);localStorage.setItem("lng", position.coords.longitude);
#                     $.get('https://ipinfo.io', function() {}, "jsonp").always(function(resp) {
#                         var cityLocation = (resp && resp.city) ? resp.city : "";
#                         callRequest({url: "/site/set-location",method: 'POST',data: {lat: position.coords.latitude, lng: position.coords.longitude, city: cityLocation, _csrf: csrfToken},beforeRequest(){
#                         },afterRequest(res){
#                             if(typeof  res == "string" && res != 1){
#                                 $('#homeSelectCity').val(res);
#                                 $('#homeSelectCity').trigger('change');
#                             }
#                         }});
#                     });
#                 },
#                 function(error){}, {enableHighAccuracy: true,timeout : 15000}
#             )
#         }
#
#         /* branch integration */
#         window.dataLayer = window.dataLayer || [];
#
#
#
#         $(".ServicesPopOver").popover({
#             html : true,
#             trigger: 'focus',
#             content: function() {
#                 var content = $(this).attr("data-popover-content");
#                 return $(content).children(".popover-body").html();
#             }
#         });
#      });
#
#
#     $(".closeAppB").on("click", function(){
#         $(".topAppBox").hide();
#     });
#     (function () {
#       var lastclear = localStorage.getItem('lastclear'),
#           time_now  = (new Date()).getTime();
#
#       if ((time_now - lastclear) > 1000 * 60 * 60 * 24) {
#         localStorage.clear();
#         localStorage.setItem('lastclear', time_now);
#       }
#     })();
#           firebase.analytics().logEvent("web_Session");
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#             })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#             ga('create', 'UA-92646752-1', 'auto');
#             ga('send', 'pageview');
#             /* init google ecommerce */
#             ga('require', 'ecommerce');
#             ga('require', 'ec');</script>
# <script>jQuery(function ($) {
#
#     window.addEventListener("load",  function(){
#         ga('send', {
#           hitType: 'event',
#           eventCategory: 'Advanced Search',
#           eventAction: 'Advanced Search Open',
#           eventLabel: 'Advanced Search Open'
#         });
#
#         ga('send', {
#           hitType: 'event',
#           eventCategory: 'Search Result Page',
#           eventAction: 'Search Result Page',
#           eventLabel: 'Search Result Page'
#         });
#     });
# });</script></body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="rtl" lang="sa-ar">
#  <!--[if IE 8]> <html lang="sa-ar" class="ie8 no-js"> <![endif]-->
#  <!--[if IE 9]> <html lang="sa-ar" class="ie9 no-js"> <![endif]-->
#  <!--[if !IE]><!-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0" name="viewport"/>
#   <title>
#    أفضل بيوت العطلات - Gathern | جاذر إن
#   </title>
#   <meta content="index,follow" name="robots"/>
#   <link href="https://gathern.co/search/main/index?r" rel="canonical"/>
#   <meta content="#5A409B" name="theme-color"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="شاليهات، منتجعات، مزارع، مخيمات، كرفانات، استراحات، فلل، شقق، شاليه، استراحة، منتجع، مخيم، مزرعة، فله، شقة، جاذر ان، gathern، اكتشف السعودية، العلا، ابها، الطائف، " name="keywords"/>
#   <meta content="أفضل بيوت العطلات (شاليهات - منتجعات فندقية - مخيمات - شقق - مزارع) و بأسعار معقولة فى منصة جاذر إن مرخصة و معتمدة من وزارة السياحة" name="description"/>
#   <meta content="FNNrctot2BoD8o3t8kOtQFItp0IItS_wRU9gR7LmVzY" name="google-site-verification"/>
#   <meta content="gU4G4gNc-9XQgc1zCxwyAEGYVvPZQMaSGevTJ1-Ia8c" name="google-site-verification"/>
#   <meta content="eacc4a2929a3b75a" name="yandex-verification"/>
#   <meta content="F5381F70BE40B0ACC55D79E8F4E8508D" name="msvalidate.01"/>
#   <meta content="Gathern Holding" name="author"/>
#   <meta content="أفضل بيوت العطلات - Gathern | جاذر إن" property="og:title"/>
#   <meta content="أفضل بيوت العطلات - Gathern | جاذر إن" name="twitter:title"/>
#   <meta content="https://gathern.co/search" property="og:url"/>
#   <meta content="أفضل بيوت العطلات - Gathern | جاذر إن" name="twitter:card"/>
#   <meta content="Gathern Holding" name="twitter:site"/>
#   <meta content="أفضل بيوت العطلات (شاليهات - منتجعات فندقية - مخيمات - شقق - مزارع) و بأسعار معقولة فى منصة جاذر إن مرخصة و معتمدة من وزارة السياحة" name="twitter:description"/>
#   <meta content="أفضل بيوت العطلات (شاليهات - منتجعات فندقية - مخيمات - شقق - مزارع) و بأسعار معقولة فى منصة جاذر إن مرخصة و معتمدة من وزارة السياحة" property="og:description"/>
#   <meta content="https://gathern.co/img/default-share-image.png" name="twitter:image"/>
#   <meta content="https://gathern.co/img/default-share-image.png" property="og:image"/>
#   <meta content="en_GB" property="og:locale"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="/assets/eb1f3e3f/css/bootstrap.min-rtl.css?v=1617006873" rel="stylesheet"/>
#   <link href="/css/collections.min.css?v=1617006873" rel="stylesheet"/>
#   <link href="/css/app-rtl.css?v=1636974751" rel="stylesheet"/>
#   <link href="/css/theme-chalk.css" rel="stylesheet"/>
#   <link href="/css/advanced-search.css?ref=24032021" rel="stylesheet"/>
#   <script>
#    var scParams = "";
#   </script>
#   <meta content="_csrf" name="csrf-param"/>
#   <meta content="oH7m-qh14fRuCaQLBcS20xz13ZPIfvuVWN_qPsn26t3iLLnL_BePoQBT035Kro6iMYK45oNGgdwPiJxakLCejA==" name="csrf-token"/>
#  </head>
#  <body class="animated">
#   <div class="container-fluid no-padding">
#    <header class="header">
#     <div class="top-menu">
#      <div class="container">
#       <div class="row">
#        <div class="col-8 col-md-2 col-lg-2 logo">
#         <a href="/" title="">
#          <img alt="جاذر إن" src="/img/Group1@2x.png"/>
#         </a>
#        </div>
#        <div class="col-2 col-md-7 col-lg-7 navMenu position-relative">
#         <nav class="navbar navbar-expand-md navbar-dark">
#          <button class="navbar-toggler" type="button">
#           <i class="fas fa-bars">
#           </i>
#          </button>
#          <div class="collapse navbar-collapse">
#           <ul class="navbar-nav mr-auto">
#            <li class="nav-item">
#             <a class="nav-link" href="/">
#              الرئيسية
#             </a>
#            </li>
#            <li>
#             <a class="nav-link" href="/chalets/all">
#              شاليهات و استراحات
#             </a>
#            </li>
#            <li>
#             <a class="nav-link" href="/camps/all">
#              مخيمات
#             </a>
#            </li>
#            <li>
#             <a class="nav-link" href="/farms/all">
#              مزارع
#             </a>
#            </li>
#            <li>
#             <a class="nav-link" href="/apartments/all">
#              فلل وشقق
#             </a>
#            </li>
#            <li>
#             <a class="nav-link" href="/special">
#              العروض
#             </a>
#            </li>
#           </ul>
#          </div>
#         </nav>
#         <div class="navbarMenu animated fadeInLeft faster">
#          <i class="fas fa-times cnavbarMenu">
#          </i>
#          <ul class="navbarMenuItems mr-auto">
#           <li>
#            <a href="/">
#             الرئيسية
#            </a>
#           </li>
#           <li>
#            <a href="#" rel="nofollow">
#             التصنيفات
#            </a>
#            <ul class="navbarMenuItemsSub">
#             <li>
#              <a href="/chalets/all">
#               <i class="fas fa-circle">
#               </i>
#               شاليهات و استراحات
#              </a>
#             </li>
#             <li>
#              <a href="/camps/all">
#               <i class="fas fa-circle">
#               </i>
#               مخيمات
#              </a>
#             </li>
#             <li>
#              <a href="/farms/all">
#               <i class="fas fa-circle">
#               </i>
#               مزارع
#              </a>
#             </li>
#             <li>
#              <a href="/apartments/all">
#               <i class="fas fa-circle">
#               </i>
#               فلل وشقق
#              </a>
#             </li>
#             <li>
#              <a href="/special">
#               <i class="fas fa-circle">
#               </i>
#               العروض
#              </a>
#             </li>
#            </ul>
#           </li>
#           <li>
#            <a href="/contact-us" rel="nofollow">
#             اتصل بنا
#            </a>
#           </li>
#          </ul>
#          <div class="mobConChooseLNG">
#           <a alt="sa-en" class="btn signupLogin mColor" href="https://gathern.co/site/lang?lang=sa-en" rel="nofollow" title="sa-en">
#            <img alt="English" data-src="/img/gb.png"/>
#            <br/>
#            English
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="col-2 col-md-3 col-lg-3 top-login">
#         <a class="btn signupLogin" href="https://gathern.co/join">
#          <i class="far fa-user">
#          </i>
#          <span>
#           تسجيل / دخول
#          </span>
#         </a>
#         <div class="ConChooseLNG">
#          <a class="btn signupLogin" href="https://gathern.co/site/lang?lang=sa-en" rel="nofollow">
#           <img alt="English" data-src="/img/gb.png"/>
#           English
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="GnBreadcrumb" itemprop="breadcrumb">
#      <div class="container">
#       <ol class="breadcrumb">
#        <li>
#         <a href="https://gathern.co">
#          الرئيسية
#         </a>
#         <i class="fas fa-chevron-left">
#         </i>
#        </li>
#        <li class="active">
#         نتائج البحث
#        </li>
#       </ol>
#      </div>
#     </div>
#    </header>
#    <main>
#     <div :class="{'searchApp--searchview': searchView}" id="searchApp">
#      <template v-if="search_meta">
#       <div class="topSerachBar" v-if="! loading">
#        <div class="container">
#         <div class="row">
#          <template v-if="!isMobile">
#           <div class="col-4 col-md-4 col-lg-4">
#            <div class="form-group">
#             <label>
#              المدينة
#             </label>
#             <div class="form-group-icon select-group">
#              <el-select :filterable="true" number="" placeholder="كل المدن" v-model.number="search_params.city">
#               <el-option :key="city.id" :label="city.name" :value="city.id" v-for="city in cities">
#               </el-option>
#              </el-select>
#             </div>
#            </div>
#           </div>
#           <div class="col-4 col-md-4 col-lg-4">
#            <div class="form-group">
#             <label>
#              الفئات
#             </label>
#             <div class="form-group-icon select-group">
#              <el-select :filterable="true" multiple="" number="" placeholder="كل الفئات" v-model="search_params.unit_cats">
#               <el-option :key="amenity" :label="amenity" :value="amenity" v-for="(amenity, key) in search_meta.unit_cats">
#               </el-option>
#              </el-select>
#             </div>
#            </div>
#           </div>
#           <div class="col-4 col-md-4 col-lg-4">
#            <div class="form-group">
#             <label>
#              تاريخ الحجز
#             </label>
#             <div class="form-group-icon select-group">
#              <el-date-picker :clearable="false" :editable="false" :picker-options="{disabledDate:checkdatisdisabled, onPick:dateChangeCheckInCheckOut}" end-placeholder="تاريخ المغادرة" format="yyyy/MM/dd" placeholder="موعد الحجز" range-separator="الى" start-placeholder="تاريخ المناسبة" type="datetimerange" v-model="search_params.checkin_checkout" value-format="yyyy-MM-dd">
#              </el-date-picker>
#              <el-input type="hidden" v-model="search_params.check_in">
#              </el-input>
#              <el-input type="hidden" v-model="search_params.check_out">
#              </el-input>
#             </div>
#            </div>
#           </div>
#          </template>
#         </div>
#        </div>
#       </div>
#      </template>
#      <div class="container">
#       <div class="row">
#        <template v-if="isMobile">
#         <div :class="{'searchApp__resultspanel--inactive': searchView}" class="mainInputAdvancedSerach" v-if="! loading">
#          <div class="advancedFilOrde">
#           <div class="row">
#            <div class="col-6">
#             <div id="filter-button">
#              <a class="btn-filter-button" href="">
#               <i class="fas fa-filter">
#               </i>
#               فلتر
#              </a>
#             </div>
#            </div>
#            <div class="col-6">
#             <div class="advacedFilDrop">
#              <button class="btn" id="sortBy" ref="button" type="button">
#               <i class="fas fa-sort">
#               </i>
#               ترتيب
#              </button>
#             </div>
#            </div>
#           </div>
#          </div>
#          <ul aria-labelledby="sortBy" class="advacedFilDropList" v-closable="{exclude: ['button'],handler: 'closeFilterOutSide' }" v-if="displayFilterDrop">
#           <li>
#            <a :class="{'advacedFilDropActive': isorderactive('rand')}" href="#">
#             <span class="el-radio__inner">
#             </span>
#             الكل
#            </a>
#           </li>
#           <li>
#            <a :class="{'advacedFilDropActive': isorderactive('rating')}" href="#">
#             <span class="el-radio__inner">
#             </span>
#             الأعلى تقييماً
#            </a>
#           </li>
#           <li>
#            <a :class="{'advacedFilDropActive': isorderactive('nearest')}" href="#">
#             <span class="el-radio__inner">
#             </span>
#             الأقرب لموقعى
#            </a>
#           </li>
#           <li>
#            <a :class="{'advacedFilDropActive': isorderactive('views_highest')}" href="#">
#             <span class="el-radio__inner">
#             </span>
#             الأعلى مشاهدة
#            </a>
#           </li>
#           <li>
#            <a :class="{'advacedFilDropActive': isorderactive('price_lowest')}" href="#">
#             <span class="el-radio__inner">
#             </span>
#             الأقل سعراً
#            </a>
#           </li>
#           <li>
#            <a :class="{'advacedFilDropActive': isorderactive('price_highest')}" href="#">
#             <span class="el-radio__inner">
#             </span>
#             الأعلى سعراً
#            </a>
#           </li>
#          </ul>
#         </div>
#        </template>
#        <div :class="{'searchApp__filterpanel--active': searchView}" class="col-12 col-md-4 col-lg-4 searchApp__filterpanel">
#         <template v-if="isMobile">
#          <i class="closeFilter fas fa-times">
#          </i>
#          <button class="btn btn-reset">
#           اعادة تعيين
#          </button>
#         </template>
#         <template v-if="search_meta">
#          <div class="accordion" id="advancedSBoxAccordion">
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-1" data-toggle="collapse">
#             <h1>
#              <span class="fas fa-search">
#              </span>
#              البحث المتقدم
#             </h1>
#             <i class="fas fa-chevron-up">
#             </i>
#            </div>
#            <div class="advancedCont collapse show" id="advancedSBox-1">
#             <template v-if="isMobile">
#              <div class="form-group">
#               <label>
#                المدينة
#               </label>
#               <div class="form-group-icon select-group">
#                <el-select :filterable="true" number="" placeholder="كل المدن" v-model.number="search_params.city">
#                 <el-option :key="city.id" :label="city.name" :value="city.id" v-for="city in cities">
#                 </el-option>
#                </el-select>
#               </div>
#              </div>
#              <div class="form-group">
#               <div class="row">
#                <div class="col-6 col-md-6 col-lg-6">
#                 <label>
#                  اسم العقار
#                 </label>
#                 <div class="form-group-icon select-group">
#                  <el-input :clearable="true" debounce="800" placeholder="اسم العقار" v-model="search_params.query" v-on:changes="handleinputChange">
#                  </el-input>
#                 </div>
#                </div>
#                <div class="col-6 col-md-6 col-lg-6">
#                 <label>
#                  رمز الوحدة
#                 </label>
#                 <div class="form-group-icon select-group">
#                  <el-input placeholder="رمز الوحدة" type="tel" v-model="search_params.unit_code">
#                  </el-input>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="form-group">
#               <div class="row">
#                <div class="col-6 col-md-6 col-lg-6">
#                 <label>
#                  اسم الحي
#                 </label>
#                 <div class="form-group-icon select-group">
#                  <el-select :filterable="true" :multiple="true" number="" placeholder="الحى" v-model="search_params.areas">
#                   <el-option :key="area.id" :label="area.name" :value="area.id" v-for="area in allselectedCityAreas">
#                   </el-option>
#                  </el-select>
#                 </div>
#                </div>
#                <div class="col-6 col-md-6 col-lg-6">
#                 <label>
#                  الاتجاهات
#                 </label>
#                 <div class="form-group-icon select-group">
#                  <el-select :filterable="true" placeholder="اختر الأتجاه" v-model="search_params.direction">
#                   <el-option :key="key" :label="dir" :value="key" v-for="(dir , key) in dirs">
#                   </el-option>
#                  </el-select>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </template>
#             <template v-else="">
#              <div class="form-group">
#               <label>
#                اسم العقار
#               </label>
#               <div class="form-group-icon select-group">
#                <el-input :clearable="true" debounce="800" placeholder="اسم العقار" v-model="search_params.query" v-on:changes="handleinputChange">
#                </el-input>
#               </div>
#              </div>
#              <div class="form-group">
#               <label>
#                اسم الحي
#               </label>
#               <div class="form-group-icon select-group">
#                <el-select :filterable="true" :multiple="true" number="" placeholder="الحى" v-model="search_params.areas">
#                 <el-option :key="area.id" :label="area.name" :value="area.id" v-for="area in allselectedCityAreas">
#                 </el-option>
#                </el-select>
#               </div>
#              </div>
#              <div class="form-group">
#               <div class="row">
#                <div class="col-6 col-md-6 col-lg-6">
#                 <label>
#                  الاتجاهات
#                 </label>
#                 <div class="form-group-icon select-group">
#                  <el-select :filterable="true" placeholder="اختر الأتجاه" v-model="search_params.direction">
#                   <el-option :key="key" :label="dir" :value="key" v-for="(dir , key) in dirs">
#                   </el-option>
#                  </el-select>
#                 </div>
#                </div>
#                <div class="col-6 col-md-6 col-lg-6">
#                 <label>
#                  رمز الوحدة
#                 </label>
#                 <div class="form-group-icon select-group">
#                  <el-input placeholder="رمز الوحدة" type="number" v-model="search_params.unit_code">
#                  </el-input>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </template>
#            </div>
#           </div>
#           <template v-if="unit_label_counts(search_meta.labels) &gt; 0">
#            <div class="advancedSBox">
#             <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-12" data-toggle="collapse">
#              <h4>
#               <span class="fas fa-tags">
#               </span>
#               اختيار جاذر إن
#              </h4>
#              <i class="fas fa-chevron-down">
#              </i>
#             </div>
#             <div class="advancedCont collapse show" id="advancedSBox-12">
#              <el-checkbox-group v-model="search_params.labels">
#               <template v-for="(label, key, index) in search_meta.labels">
#                <el-checkbox :label="label.id">
#                 <b>
#                  {{ label.value }}
#                 </b>
#                 <p>
#                  {{ label.description }}
#                 </p>
#                </el-checkbox>
#               </template>
#              </el-checkbox-group>
#             </div>
#            </div>
#           </template>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-2" data-toggle="collapse">
#             <h4>
#              <span class="fas fa-search-dollar">
#              </span>
#              السعر
#             </h4>
#             <i class="fas fa-chevron-down">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-2">
#             <div class="form-group sliderRange">
#              <template>
#               <vue-slider :drag-end="stopDropPrice = true" :interval="100" :lazy="true" :max="10000" :min="0" :tooltip="'always'" :tooltipplacement="'top'" ref="slider" v-model="search_params.prices_units">
#               </vue-slider>
#              </template>
#             </div>
#            </div>
#           </div>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-3" data-toggle="collapse">
#             <h2>
#              <span class="fas fa-store-alt">
#              </span>
#              نوع العقار
#             </h2>
#             <i class="fas fa-chevron-down">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-3">
#             <el-checkbox-group v-model="search_params.chalet_cats">
#              <template v-for="(cat, key, index) in search_meta.chalet_cats">
#               <el-checkbox :label="cat">
#               </el-checkbox>
#              </template>
#             </el-checkbox-group>
#            </div>
#           </div>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-4" data-toggle="collapse">
#             <h4>
#              <span class="fas fa-restroom">
#              </span>
#              السعة
#             </h4>
#             <i class="fas fa-chevron-down">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-4">
#             <el-checkbox-group v-model="search_params.capacity_units">
#              <template v-for="(capacity, key, index) in search_meta.capacity_units">
#               <el-checkbox :label="capacity">
#               </el-checkbox>
#              </template>
#             </el-checkbox-group>
#            </div>
#           </div>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-9" data-toggle="collapse">
#             <h4>
#              <span class="fas fa-bed">
#              </span>
#              غرف النوم و الأسرّة
#             </h4>
#             <i class="fas fa-chevron-down">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-9">
#             <div class="row">
#              <template>
#               <div class="col-4 col-lg-4">
#                <span>
#                 عدد الغرف
#                </span>
#               </div>
#               <div class="col-8 col-lg-8">
#                <el-input-number :max="10" :min="0" class="plusMinJsInput" v-model="search_params.total_rooms">
#                </el-input-number>
#                <span class="defaultValInputPr">
#                 -
#                </span>
#               </div>
#              </template>
#              <template>
#               <div class="col-4 col-lg-4">
#                <span>
#                 سرير مفرد
#                </span>
#               </div>
#               <div class="col-8 col-lg-8">
#                <el-input-number :max="10" :min="0" class="plusMinJsInput" v-model="search_params.total_single_beds">
#                </el-input-number>
#                <span class="defaultValInputPs">
#                 -
#                </span>
#               </div>
#              </template>
#              <template>
#               <div class="col-4 col-lg-4">
#                <span>
#                 سرير ماستر
#                </span>
#               </div>
#               <div class="col-8 col-lg-8">
#                <el-input-number :max="10" :min="0" class="plusMinJsInput" v-model="search_params.total_master_beds">
#                </el-input-number>
#                <span class="defaultValInputPm">
#                 -
#                </span>
#               </div>
#              </template>
#             </div>
#            </div>
#           </div>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-5" data-toggle="collapse">
#             <h4>
#              <span class="far fa-star">
#              </span>
#              التقييم
#             </h4>
#             <i class="fas fa-chevron-down">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-5">
#             <el-checkbox-group v-model="search_params.unit_reviews">
#              <template v-for="(review, key, index) in search_meta.unit_reviews">
#               <el-checkbox :label="review">
#               </el-checkbox>
#              </template>
#             </el-checkbox-group>
#            </div>
#           </div>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-50" data-toggle="collapse">
#             <h4>
#              <span class="far fa-star">
#              </span>
#              الفئات
#             </h4>
#             <i class="fas fa-venus-double">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-50">
#             <el-checkbox-group v-model="search_params.unit_cats">
#              <template v-for="(cat, key, index) in search_meta.unit_cats">
#               <el-checkbox :label="cat">
#               </el-checkbox>
#              </template>
#             </el-checkbox-group>
#            </div>
#           </div>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-6" data-toggle="collapse">
#             <h4>
#              <span class="fas fa-swimming-pool">
#              </span>
#              المسبح
#             </h4>
#             <i class="fas fa-chevron-down">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-6">
#             <el-checkbox-group v-model="search_params.pool_types">
#              <template v-for="(type, key, index) in search_meta.pool_types">
#               <el-checkbox :label="type" v-model="search_params.pool_types">
#               </el-checkbox>
#              </template>
#             </el-checkbox-group>
#            </div>
#           </div>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-7" data-toggle="collapse">
#             <h4>
#              <span class="fas fa-wifi">
#              </span>
#              المرافق
#             </h4>
#             <i class="fas fa-chevron-down">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-7">
#             <el-checkbox-group v-model="search_params.amenities">
#              <template v-for="(amenity, key, index) in search_meta.amenities">
#               <el-checkbox :label="amenity">
#               </el-checkbox>
#              </template>
#             </el-checkbox-group>
#            </div>
#           </div>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-10" data-toggle="collapse">
#             <h4>
#              <span class="fas fa-utensils">
#              </span>
#              مرافق المطبخ
#             </h4>
#             <i class="fas fa-chevron-down">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-10">
#             <el-checkbox-group v-model="search_params.kitchen_amenities">
#              <template v-for="(amenity, key, index) in search_meta.kitchen_amenities">
#               <el-checkbox :label="amenity">
#               </el-checkbox>
#              </template>
#             </el-checkbox-group>
#            </div>
#           </div>
#           <div class="advancedSBox">
#            <div class="advancedTit" data-parent="#advancedSBoxAccordion" data-target="#advancedSBox-11" data-toggle="collapse">
#             <h4>
#              <span class="fas fa-bath">
#              </span>
#              مرافق دورات المياه
#             </h4>
#             <i class="fas fa-chevron-down">
#             </i>
#            </div>
#            <div class="advancedCont collapse" id="advancedSBox-11">
#             <el-checkbox-group v-model="search_params.toilet_amenities">
#              <template v-for="(amenity, key, index) in search_meta.toilet_amenities">
#               <el-checkbox :label="amenity">
#               </el-checkbox>
#              </template>
#             </el-checkbox-group>
#            </div>
#           </div>
#          </div>
#         </template>
#         <template v-if="isMobile">
#          <div class="advancedTotalResultBox">
#           <div class="row">
#            <div class="col-6">
#             <template v-if="total_count &gt;= 300">
#              <span class="totalResultCount">
#               +300 مكان الإقامة
#              </span>
#             </template>
#             <template v-else="">
#              <span class="totalResultCount">
#               ({{ total_count }}) مكان الإقامة
#              </span>
#             </template>
#            </div>
#            <div class="col-6">
#             <el-button :disabled="total_count &lt; 1" :loading="loading" class="mainFilterSearchBtn" type="primary">
#              <i :loading="loading">
#              </i>
#              اظهر النتائج
#             </el-button>
#            </div>
#           </div>
#          </div>
#         </template>
#        </div>
#        <div :class="{'searchApp__resultspanel--inactive': searchView}" class="col-12 col-md-8 col-lg-8 pr-0 searchApp__resultspanel fresult" id="mainresultscontainer">
#         <div class="main-content">
#          <template v-if="!isMobile">
#           <ul :class="{'searchApp__filterpanel--active': searchView}" class="advancedFilter" v-if="search_meta">
#            <li class="Filterer__list__item">
#             <a :class="{'Filterer__button--is-active': isorderactive('rand')}" class="Filterer__button" href="#">
#              الكل
#             </a>
#            </li>
#            <li class="Filterer__list__item">
#             <a :class="{'Filterer__button--is-active': isorderactive('rating')}" class="Filterer__button" href="#">
#              الأعلى تقييماً
#             </a>
#            </li>
#            <li class="Filterer__list__item">
#             <a :class="{'Filterer__button--is-active': isorderactive('nearest')}" class="Filterer__button" href="#">
#              الأقرب لموقعى
#             </a>
#            </li>
#            <li class="Filterer__list__item">
#             <a :class="{'Filterer__button--is-active': isorderactive('views_highest')}" class="Filterer__button" href="#">
#              الأعلى مشاهدة
#             </a>
#            </li>
#            <li class="Filterer__list__item">
#             <a :class="{'Filterer__button--is-active': isorderactive('price_lowest')}" class="Filterer__button" href="#">
#              الأقل سعراً
#             </a>
#            </li>
#            <li class="Filterer__list__item">
#             <a :class="{'Filterer__button--is-active': isorderactive('price_highest')}" class="Filterer__button" href="#">
#              الأعلى سعراً
#             </a>
#            </li>
#           </ul>
#          </template>
#          <template v-if="loading">
#           <content-placeholder :rows="placeholderRows" class="content-placeholder">
#           </content-placeholder>
#          </template>
#          <div class="items-lists" v-if="! loading">
#           <template v-for="unitAds in total_results_ads">
#            <div :data-id="unitAds.unit_id" class="ChaletItemBox ChaletItemBox--unit" v-bind:class="{ bgAdvColor: unitAds.is_ads}" v-view.once="viewHandler">
#             <div class="ChaletItemBox__thumb">
#              <div class="ChaletItemContSlider">
#               <div class="ChaletItemBoxSlider owl-carousel owl-theme">
#                <a :href="unit_view_link(unitAds)" :title="unitAds.title" class="ChaletItemLinkAds" target="_blank" v-for="unit_mage in unit_cover(unitAds)">
#                 <div class="slideImg">
#                  <img :alt="unitAds.title" :data-src="unit_mage" class="img-responsive owl-lazy"/>
#                 </div>
#                </a>
#               </div>
#              </div>
#              <div class="ChaletItemBox_view">
#               <i class="fa fa-eye">
#               </i>
#               {{ unitAds.views_count_k }}
#              </div>
#              <template v-if="unitAds.isUnitAvailable == false">
#               <div class="notAvialbelUnitDate">
#                <span>
#                 محجوز فى هذا التاريخ
#                </span>
#               </div>
#              </template>
#              <template v-if="unitAds.is_ads">
#               <label class="adsChaletLabel">
#                إعلان
#               </label>
#              </template>
#             </div>
#             <div class="ChaletItemBox__content">
#              <div class="row padd18">
#               <div class="col-md-7 col-xs-9">
#                <h3 class="ChaletItemBox__content__name__ads">
#                 <a :href="unit_view_link(unitAds)" :title="unitAds.title" target="_blank">
#                  {{ unitAds.chalet_title }}
#                  <br/>
#                  <span>
#                   {{ unitAds.title }}
#                  </span>
#                 </a>
#                </h3>
#                <div class="col-md-12 col-xs-12 pr-0 rateNewCont">
#                 <i class="fa fa-star starColor">
#                 </i>
#                 <b>
#                  {{ unitAds.total_present }}
#                 </b>
#                 ({{ unitAds.total_reviews }}) تقييم
#                </div>
#                <div class="col-md-12 col-xs-12 pr-0">
#                 <p class="ChaletItemBoxLocation">
#                  <i class="fa fa-map-marker">
#                  </i>
#                  <span>
#                   {{ unitAds.address.city }}
#                  </span>
#                  ,
#                  <span>
#                   {{ unitAds.address.area }}
#                  </span>
#                 </p>
#                </div>
#                <div class="col-md-12 col-xs-12 pr-0">
#                 <template v-if="unitAds.booking_count &gt; 0">
#                  <div class="ChaletItemBookingCount">
#                   تم حجزه {{ unitAds.booking_count }} مرات هذا الاسبوع
#                  </div>
#                 </template>
#                </div>
#               </div>
#               <div class="col-md-5 col-xs-3 priceLineRight">
#                <div class="contPRicing">
#                 <template v-if="unitAds.label">
#                  <div class="label">
#                   <span :style="{'background-color':unitAds.label['color']}">
#                    {{ unitAds.label['label'] }}
#                   </span>
#                  </div>
#                 </template>
#                 <div class="ChaletItemPrice">
#                  <template v-if="unitAds.has_cancel_price">
#                   <div class="ChaletItemPrice__Old">
#                    <b>
#                     {{ unitAds.cancel_price_format }}
#                    </b>
#                    ر.س
#                   </div>
#                  </template>
#                  <div class="ChaletItemPrice__New">
#                   <b>
#                    {{ unitAds.avg_price_format }}
#                   </b>
#                   ر.س
#                   <span class="nightsSlashSpan no-padding">
#                    /
#                   </span>
#                   <span class="nightsSpan">
#                    {{ unitAds.day_flag }}
#                   </span>
#                   <el-popover placement="top" title="تفاصيل السعر" v-model="tipVisibles[unitAds.id]" width="240">
#                    <span class="closePopServ">
#                     X
#                    </span>
#                    <div class="row servicesPriceCont">
#                     <div class="col-7 col-md-7">
#                      {{ unitAds.day_price_format }} x
#                      <span class="unicode-bidi">
#                       {{ unitAds.nights }}
#                       <template v-if="unitAds.nights &gt; 1">
#                        ليالى
#                       </template>
#                       <template v-else="">
#                        ليلة
#                       </template>
#                      </span>
#                     </div>
#                     <div class="col-5 col-md-5">
#                      {{ unitAds.price_before_discount }} ر.س
#                     </div>
#                     <template v-for="service in unitAds.services">
#                      <div class="col-7 col-md-7" style="font-size: 11px;" v-bind:class="{ servDiscountTitle:  service.id == 0}">
#                       {{ service.title }}
#                      </div>
#                      <div class="col-5 col-md-5" v-bind:class="{ servDiscountAmount:  service.id == 0}">
#                       {{ service.amount_value }} ر.س
#                      </div>
#                     </template>
#                    </div>
#                    <span class="servicesPrice" slot="reference">
#                     {{ unitAds.final_price_services }} ر.س القيمة الإجمالية
#                    </span>
#                   </el-popover>
#                  </div>
#                 </div>
#                </div>
#                <div class="text-center">
#                 <a :href="unit_view_link(unitAds)" class="btn btnViewUnitSearch" target="_blank">
#                  تفاصيل
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </template>
#           <template v-if="! loading">
#            <div class="alert alert-warning" role="alert" v-if="! hasResults">
#             لم يتم العثور على نتائج توافق بحثك
#            </div>
#           </template>
#           <template v-for="unit in total_results">
#            <div :class="{ 'widgetBusyUnit' : unit.isUnitAvailable == false}" :data-id="unit.unit_id" class="ChaletItemBox ChaletItemBox--unit" v-view="viewUnitsHandler" v-view.once="viewHandler">
#             <div class="ChaletItemBox__thumb">
#              <div class="ChaletItemContSlider">
#               <div class="ChaletItemBoxSlider owl-carousel owl-theme">
#                <a :href="unit_view_link(unit)" :title="unit.title" class="ChaletItemLinkAds" target="_blank" v-for="unit_mage in unit_cover(unit)">
#                 <div class="slideImg">
#                  <img :alt="unit.title" :data-src="unit_mage" class="img-responsive owl-lazy"/>
#                 </div>
#                </a>
#               </div>
#              </div>
#              <div class="ChaletItemBox_view">
#               <i class="fa fa-eye">
#               </i>
#               {{ unit.views_count_k }}
#              </div>
#              <template v-if="unit.isUnitAvailable == false">
#               <div class="notAvialbelUnitDate">
#                <span>
#                 محجوز فى هذا التاريخ
#                </span>
#               </div>
#              </template>
#             </div>
#             <div class="ChaletItemBox__content">
#              <div class="row padd18">
#               <div class="col-md-7 col-9">
#                <h3>
#                 <a :href="unit_view_link(unit)" :title="unit.title" target="_blank">
#                  {{ unit.chalet_title }}
#                  <br/>
#                  <span>
#                   {{ unit.title }}
#                  </span>
#                 </a>
#                </h3>
#                <div class="col-md-12 col-12 pr-0 rateNewCont">
#                 <i class="fa fa-star starColor">
#                 </i>
#                 <b>
#                  {{ unit.total_present }}
#                 </b>
#                 ({{ unit.total_reviews }}) تقييم
#                </div>
#                <div class="col-md-12 col-12 pr-0">
#                 <p class="ChaletItemBoxLocation">
#                  <i class="fa fa-map-marker">
#                  </i>
#                  <span>
#                   {{ unit.address.city }}
#                  </span>
#                  ,
#                  <span>
#                   {{ unit.address.area }}
#                  </span>
#                 </p>
#                </div>
#                <div class="col-md-12 col-12 pr-0">
#                 <template v-if="unit.booking_count &gt; 0">
#                  <div class="ChaletItemBookingCount">
#                   تم حجزه {{ unit.booking_count }} مرات هذا الاسبوع
#                  </div>
#                 </template>
#                </div>
#               </div>
#               <div class="col-md-5 col-3 priceLineRight">
#                <template v-if="unit.label">
#                 <div class="label">
#                  <span :style="{'background-color':unit.label['color']}">
#                   {{ unit.label['label'] }}
#                  </span>
#                 </div>
#                </template>
#                <div class="contPRicing">
#                 <div class="ChaletItemPrice">
#                  <template v-if="unit.has_cancel_price">
#                   <div class="ChaletItemPrice__Old">
#                    <b>
#                     {{ unit.cancel_price_format }}
#                    </b>
#                    ر.س
#                   </div>
#                  </template>
#                  <div class="ChaletItemPrice__New">
#                   <b>
#                    {{ unit.avg_price_format }}
#                   </b>
#                   ر.س
#                   <span class="nightsSlashSpan no-padding">
#                    /
#                   </span>
#                   <span class="nightsSpan">
#                    {{ unit.day_flag }}
#                   </span>
#                   <el-popover placement="top" title="تفاصيل السعر" v-model="tipVisibles[unit.id]" width="240">
#                    <span class="closePopServ">
#                     X
#                    </span>
#                    <div class="row servicesPriceCont">
#                     <div class="col-7 col-md-7">
#                      {{ unit.day_price_format }} x
#                      <span class="unicode-bidi">
#                       {{ unit.nights }}
#                       <template v-if="unit.nights &gt; 1">
#                        ليالى
#                       </template>
#                       <template v-else="">
#                        ليلة
#                       </template>
#                      </span>
#                     </div>
#                     <div class="col-5 col-md-5">
#                      {{ unit.price_before_discount }} ر.س
#                     </div>
#                     <template v-for="service in unit.services">
#                      <div class="col-7 col-md-7" style="font-size: 11px;" v-bind:class="{ servDiscountTitle:  service.id == 0}">
#                       {{ service.title }}
#                      </div>
#                      <div class="col-5 col-md-5" v-bind:class="{ servDiscountAmount:  service.id == 0}">
#                       {{ service.amount_value }} ر.س
#                      </div>
#                     </template>
#                    </div>
#                    <span class="servicesPrice" slot="reference">
#                     {{ unit.final_price_services }} ر.س القيمة الإجمالية
#                    </span>
#                   </el-popover>
#                  </div>
#                 </div>
#                </div>
#                <div class="text-center">
#                 <a :href="unit_view_link(unit)" class="btn btnViewUnitSearch" style="bottom: 0" target="_blank">
#                  تفاصيل
#                 </a>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </template>
#          </div>
#          <!-- ./items-lists-->
#          <!-- pagination -->
#          <el-pagination :current-page="search_params.page" :total="total_count" background="" layout="prev, pager, next" v-on:current-change="handle_pagination">
#          </el-pagination>
#         </div>
#         <!-- ./main-content-->
#        </div>
#       </div>
#       <div class="row" id="tags_links">
#        <div class="col-12" style="margin: 10px 0px 20px 0px;">
#         <template v-for="searchTag in total_search_tags" v-if="!loading &amp;&amp; total_search_tags.length">
#          <a :href="searchTag.url" :title="searchTag.title" style="float: right;margin-left: 10px;margin-bottom: 10px;border: 1px solid #e0e0e0;border-radius: 5px;padding: 10px;color: #838499;" target="_blank">
#           <i class="fas fa-circle" style="color: #fdcd05;">
#           </i>
#           {{ searchTag.subtitle }}
#          </a>
#         </template>
#        </div>
#       </div>
#      </div>
#     </div>
#    </main>
#    <footer>
#     <div class="container">
#      <div class="row">
#       <div class="col-12 col-md-4 col-lg-4">
#        <div class="foolgo">
#         <a href="/">
#          <img alt="جاذر إن" class="img-responsive" data-src="/img/Group1@2x.png"/>
#         </a>
#        </div>
#        <div class="foosup">
#         <div class="foosupimg">
#          <img alt="خدمة العملاء" class="img-responsive" data-src="/img/operator-27@2x.png"/>
#         </div>
#         <div class="foosupcon">
#          <p>
#           خدمة العملاء
#          </p>
#          <p>
#           <a href="tel:920007858">
#            920007858
#           </a>
#          </p>
#          <p>
#           9:30 am - 12:00 am
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="col-6 col-md-4 col-lg-4 fooLinksCol">
#        <h3 class="fooHeadline">
#         روابط سريعة
#        </h3>
#        <ul class="fooLinks">
#         <li>
#          <a href="/" title="">
#           الرئيسية
#          </a>
#         </li>
#         <li>
#          <a href="/page/terms" rel="nofollow" title="">
#           شروط الإستخدام
#          </a>
#         </li>
#         <li>
#          <a href="/faqs/customer" rel="nofollow" title="">
#           الاسئلة المتكررة
#          </a>
#         </li>
#         <li>
#          <a href="/special" title="">
#           العروض
#          </a>
#         </li>
#         <li>
#          <a href="/contact-us" rel="nofollow" title="">
#           اتصل بنا
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-12 col-md-4 col-lg-4">
#        <h3 class="fooHeadline hideInMobile">
#         جاذر إن  على السوشيال ميديا
#        </h3>
#        <ul class="fooLinksSoc">
#         <li>
#          <a href="https://www.youtube.com/channel/UCHj6Azkw15xvh_Fs6KwiRDA" rel="noopener" target="_blank" title="youtube">
#           <img alt="youtube" class="img-responsive" data-src="/img/youtube-44.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.instagram.com/gathernApp/" rel="noopener" target="_blank" title="instagram">
#           <img alt="instagram" class="img-responsive" data-src="/img/instagram-41.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="https://www.facebook.com/gather.n1/" rel="noopener" target="_blank" title="facebook">
#           <img alt="facebook" class="img-responsive" data-src="/img/facebook-41.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="https://twitter.com/gathernApp" rel="noopener" target="_blank" title="twitter">
#           <img alt="twitter" class="img-responsive" data-src="/img/twitter-42.png"/>
#          </a>
#         </li>
#         <li>
#          <a href="#" rel="noopener" target="_blank" title="snapchat">
#           <img alt="snapchat" class="img-responsive" data-src="/img/snapchat-23.png"/>
#          </a>
#         </li>
#        </ul>
#        <p class="fooCopyRight">
#         جميع الحقوق محفوظة © 2016 - 2021 جاذر إن
#        </p>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <div class="modal fade modal-fullscreen" id="panorama-modal" role="dialog" tabindex="-1">
#    <div class="modal-dialog" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <h4 class="modal-title d-none" id="">
#        صور بانورامية
#       </h4>
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <i class="far fa-window-close">
#        </i>
#       </button>
#      </div>
#      <div class="modal-body">
#       <div id="lightbox-panorama">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="modalLabel" class="modal fade" id="GNModalUp" role="dialog" style="    z-index: 10051;" tabindex="-1">
#    <div class="modal-dialog" role="document" style="width: 400px;left: 17px;">
#     <div class="modal-content">
#      <div class="modal-body">
#       ...
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="modalLabel" class="modal fade" id="GNModal" role="dialog" tabindex="-1">
#    <div class="modal-dialog" role="document">
#     <div class="modal-content">
#      <div class="modal-body">
#       ...
#      </div>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" aria-labelledby="modalLabel" class="modal fade" id="GNModalBig" role="dialog">
#    <div class="modal-dialog" role="document" style="width: 900px;">
#     <div class="modal-content">
#      <div class="modal-body">
#       ...
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    checkinVar = "2021-11-23";
#     logoUrl = "https://gathern.co/images/logo.png";
#     webSocketUrl = "wss://gathern.co/webscoket";
#     csrfToken = "oH7m-qh14fRuCaQLBcS20xz13ZPIfvuVWN_qPsn26t3iLLnL_BePoQBT035Kro6iMYK45oNGgdwPiJxakLCejA==";
#     checkInDate = "2021-11-23";
#     checkOutDate = "2021-11-24";
#     GN_lang = "ar";
#   </script>
#   <script src="/assets/2587954e/jquery.js?v=1490036520">
#   </script>
#   <script src="/assets/eb1f3e3f/js/bootstrap.bundle.min.js?v=1597486042">
#   </script>
#   <!--[if lt IE 9]>
# <script src="/assets/bf4b8ce/dist/html5shiv.min.js?v=1437422640"></script>
# <![endif]-->
#   <script data-auto-replace-svg="nest" src="/plugins/fontawesome/js/all.min.js?v=1597486042">
#   </script>
#   <script src="/js/collectionsCustom.min.js?v=1616674119">
#   </script>
#   <script src="/js/firebase.min.js?v=1612956581">
#   </script>
#   <script src="/js/app.js?v=1622720590">
#   </script>
#   <script src="/js/advanced-search.js?ref=24032021">
#   </script>
#   <script>
#    window.addEventListener("load", function(){
#
#          if (navigator.geolocation && localStorage.getItem('lat') == null) {
#             navigator.geolocation.getCurrentPosition(
#                 function(position) {
#                     localStorage.setItem("lat", position.coords.latitude);localStorage.setItem("lng", position.coords.longitude);
#                     $.get('https://ipinfo.io', function() {}, "jsonp").always(function(resp) {
#                         var cityLocation = (resp && resp.city) ? resp.city : "";
#                         callRequest({url: "/site/set-location",method: 'POST',data: {lat: position.coords.latitude, lng: position.coords.longitude, city: cityLocation, _csrf: csrfToken},beforeRequest(){
#                         },afterRequest(res){
#                             if(typeof  res == "string" && res != 1){
#                                 $('#homeSelectCity').val(res);
#                                 $('#homeSelectCity').trigger('change');
#                             }
#                         }});
#                     });
#                 },
#                 function(error){}, {enableHighAccuracy: true,timeout : 15000}
#             )
#         }
#
#         /* branch integration */
#         window.dataLayer = window.dataLayer || [];
#
#
#
#         $(".ServicesPopOver").popover({
#             html : true,
#             trigger: 'focus',
#             content: function() {
#                 var content = $(this).attr("data-popover-content");
#                 return $(content).children(".popover-body").html();
#             }
#         });
#      });
#
#
#     $(".closeAppB").on("click", function(){
#         $(".topAppBox").hide();
#     });
#     (function () {
#       var lastclear = localStorage.getItem('lastclear'),
#           time_now  = (new Date()).getTime();
#
#       if ((time_now - lastclear) > 1000 * 60 * 60 * 24) {
#         localStorage.clear();
#         localStorage.setItem('lastclear', time_now);
#       }
#     })();
#           firebase.analytics().logEvent("web_Session");
#         (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                 (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                 m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#             })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#             ga('create', 'UA-92646752-1', 'auto');
#             ga('send', 'pageview');
#             /* init google ecommerce */
#             ga('require', 'ecommerce');
#             ga('require', 'ec');
#   </script>
#   <script>
#    jQuery(function ($) {
#
#     window.addEventListener("load",  function(){
#         ga('send', {
#           hitType: 'event',
#           eventCategory: 'Advanced Search',
#           eventAction: 'Advanced Search Open',
#           eventLabel: 'Advanced Search Open'
#         });
#
#         ga('send', {
#           hitType: 'event',
#           eventCategory: 'Search Result Page',
#           eventAction: 'Search Result Page',
#           eventLabel: 'Search Result Page'
#         });
#     });
# });
#   </script>
#  </body>
# </html>

# %%
#Extract title

# %%
soup.find('title')
# Out:
# <title>أفضل بيوت العطلات - Gathern | جاذر إن</title>

# %%
title_string = soup.find('title').text

title_string
# Out:
# 'أفضل بيوت العطلات - Gathern | جاذر إن'

# %%
title_string.split('-')
# Out:
# ['أفضل بيوت العطلات ', ' Gathern | جاذر إن']

# %%
title = title_string.split('-')[0].strip()

title
# Out:
# 'أفضل بيوت العطلات'

# %%
for element in soup.find_all(class_='_urq7mym'):
    print(element.prettify())
