# %% [markdown]
# # Simple EDA and data formatting

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns 
# this statement allows the visuals to render within your Jupyter Notebook
# %matplotlib inline 
# You can configure the format of the images: ‘png’, ‘retina’, ‘jpeg’, ‘svg’, ‘pdf’.
# %config InlineBackend.figure_format = 'png'

# %%
df = pd.read_csv('Amazom_BestSeller_Products.csv', sep='\t')

# %%
df.head(50)
# Out:
#      i                                           pro_name            pro_rate  \
# 0    0  SAMSUNG Galaxy M12 Dual SIM Smartphone - 64GB,...  4.1 out of 5 stars
# 1    1  SAMSUNG Galaxy A12 Dual SIM Smartphone - 64GB,...  3.0 out of 5 stars
# 2    2  Samsung Galaxy A12 LTE Dual SIM Smartphone - 6...  1.0 out of 5 stars
# 3    3               Apple 20W USB-C Power Adapter, White  4.5 out of 5 stars
# 4    4                              New Apple Airpods Pro  4.3 out of 5 stars
# 5    5  Anker PowerCore Select 20000, 20000mAh Power B...  4.0 out of 5 stars
# 6    6  Samsung Galaxy A72 | Ultra High-Res Quad Camer...  4.2 out of 5 stars
# 7    7                   Apple AirPods with Charging Case  4.1 out of 5 stars
# 8    8  SAMSUNG Galaxy M12 Dual SIM Smartphone - 64GB,...  4.5 out of 5 stars
# 9    9  SAMSUNG Galaxy M12 Dual SIM Smartphone - 64GB,...  4.2 out of 5 stars
# 10  10  Apple iPhone 12 Pro With FaceTime (256GB) - Pa...  4.2 out of 5 stars
# 11  11  Apple Watch Series 6 (GPS, 44mm) - Space Grey ...  4.6 out of 5 stars
# 12  12  EZVIZ C6N Pan/Tilt Camera FHD Indoor,1080p WiF...  4.2 out of 5 stars
# 13  13  Anker Alkaline AA Batteries (8-Pack), Long-Las...  4.7 out of 5 stars
# 14  14  Apple iPhone 12 Pro With FaceTime (128GB) - Pa...  4.2 out of 5 stars
# 15  15  Stylus Pen for iPad with Palm Rejection, Activ...  3.4 out of 5 stars
# 16  16  Anker Nano iPhone Charger, 20W PIQ 3.0 Durable...  4.2 out of 5 stars
# 17  17  Anker Alkaline AAA Batteries (8-Pack), Long-La...  4.6 out of 5 stars
# 18  18  JBL Flip 5 Portable Speaker Waterproof Wireles...  4.6 out of 5 stars
# 19  19  Apple iPhone 12 Pro Max With FaceTime (128GB) ...  4.4 out of 5 stars
# 20  20                 New Apple AirPods (3rd generation)  4.4 out of 5 stars
# 21  21  Sony WH-1000XM4 Wireless Noise Cancelling Blue...  4.4 out of 5 stars
# 22  22                         ستيك مي للتلفزيون من شاومي  4.0 out of 5 stars
# 23  23  Xiaomi Redmi 9A Dual SIM, 32GB, 2GB RAM, 4G LT...  4.0 out of 5 stars
# 24  24  Apple Watch Series 6 (GPS, 44mm) - Blue Alumin...  4.6 out of 5 stars
# 25  25  Sony WI-C200 Wireless In-ear Bluetooth Headpho...  3.8 out of 5 stars
# 26  26  Anker USB C to Lightning Cable (6 ft), Powerli...  4.0 out of 5 stars
# 27  27  All-new Kindle Paperwhite (8GB) - Now with a 6...  4.5 out of 5 stars
# 16             4.2        135             135.0     SAR 44.00
# 17             4.6         71              71.0     SAR 14.00
# 18             4.6     23,516           23516.0    SAR 249.00
# 19             4.4        547             547.0  SAR 5,199.00
# 20             4.4         26              26.0    SAR 829.00
# 21             4.4         63              63.0    SAR 980.00
# 22             4.0        139             139.0    SAR 162.00
# 23             4.0        157             157.0    SAR 319.00
# 24             4.6        307             307.0  SAR 1,349.00
# 25             3.8        263             263.0     SAR 93.00
# 26             4.0          9               9.0     SAR 46.95
# 27             4.5          5               5.0    SAR 459.00
# 28             4.0        314             314.0    SAR 143.20
# 29             3.8      2,095            2095.0    SAR 127.20
# 30             4.3        392             392.0     SAR 98.00
# 31             4.2      3,504            3504.0     SAR 40.80
# 32             4.4        355             355.0  SAR 3,199.00
# 33             3.8         13              13.0    SAR 778.00
# 34             4.0      5,917            5917.0    SAR 190.00
# 35             4.2     17,965           17965.0     SAR 28.15
# 36             4.6     11,999           11999.0    SAR 249.00
# 37             4.3      2,355            2355.0    SAR 727.00
# 38             4.6        307             307.0  SAR 1,199.00
# 39             3.5         62              62.0  SAR 2,299.00
# 40             4.3         40              40.0  SAR 3,888.00
# 41             4.6        407             407.0    SAR 149.00
# 42             4.5     31,735           31735.0    SAR 209.00
# 43             4.4        547             547.0  SAR 4,399.00
# 44             4.3         61              61.0    SAR 143.00
# 45             4.4        355             355.0  SAR 3,299.00
# 46             5.0          7               7.0     SAR 26.00
# 47             4.1         15              15.0  SAR 1,779.00
# 48             4.5         18              18.0     SAR 59.00
# 49             4.7      7,992            7992.0     SAR 37.00
#
#     pro_price_clean  i.1
# 0            499.00    0
# 1            539.00    1
# 2            539.00    2
# 3             79.00    3
# 4            749.00    4
# 5             94.00    5
# 6           1499.00    6
# 7            475.00    7
# 8            499.00    8
# 9            499.00    9
# 10          4199.00   10
# 11          1349.00   11
# 12            98.00   12
# 13            14.00   13
# 14          3999.00   14
# 15            58.75   15
# 16            44.00   16
# 17            14.00   17
# 18           249.00   18
# 19          5199.00   19
# 20           829.00   20
# 21           980.00   21
# 22           162.00   22
# 23           319.00   23
# 24          1349.00   24
# 25            93.00   25
# 26            46.95   26
# 27           459.00   27
# 28           143.20   28
# 29           127.20   29
# 30            98.00   30
# 31            40.80   31
# 32          3199.00   32
# 33           778.00   33
# 34           190.00   34
# 35            28.15   35
# 36           249.00   36
# 37           727.00   37
# 38          1199.00   38
# 39          2299.00   39
# 40          3888.00   40
# 41           149.00   41
# 42           209.00   42
# 43          4399.00   43
# 44           143.00   44
# 45          3299.00   45
# 46            26.00   46
# 47          1779.00   47
# 48            59.00   48
# 49            37.00   49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1150 entries, 0 to 1149
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   i                 1150 non-null   int64
#  1   pro_name          1150 non-null   object
#  2   pro_rate          1040 non-null   object
#  3   pro_rate_clean    1040 non-null   float64
#  4   review_num        1040 non-null   object
#  5   review_num_clean  1040 non-null   float64
#  6   pro_price         1117 non-null   object
#  7   pro_price_clean   1117 non-null   float64
#  8   i.1               1150 non-null   int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 81.0+ KB

# %%
df.shape
# Out:
# (1150, 9)

# %%
df.isna().sum()
# Out:
# i                     0
# pro_name              0
# pro_rate            110
# pro_rate_clean      110
# review_num          110
# review_num_clean    110
# pro_price            33
# pro_price_clean      33
# i.1                   0
# dtype: int64

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# i                   0
# pro_name            0
# pro_rate            0
# pro_rate_clean      0
# review_num          0
# review_num_clean    0
# pro_price           0
# pro_price_clean     0
# i.1                 0
# dtype: int64

# %%
df.head()
# Out:
#    i                                           pro_name            pro_rate  \
# 0  0  SAMSUNG Galaxy M12 Dual SIM Smartphone - 64GB,...  4.1 out of 5 stars
# 1  1  SAMSUNG Galaxy A12 Dual SIM Smartphone - 64GB,...  3.0 out of 5 stars
# 2  2  Samsung Galaxy A12 LTE Dual SIM Smartphone - 6...  1.0 out of 5 stars
# 3  3               Apple 20W USB-C Power Adapter, White  4.5 out of 5 stars
# 4  4                              New Apple Airpods Pro  4.3 out of 5 stars
#
#    pro_rate_clean review_num  review_num_clean   pro_price  pro_price_clean  \
# 0             4.1         40              40.0  SAR 499.00            499.0
# 1             3.0          2               2.0  SAR 539.00            539.0
# 2             1.0          2               2.0  SAR 539.00            539.0
# 3             4.5        363             363.0   SAR 79.00             79.0
# 4             4.3      2,355            2355.0  SAR 749.00            749.0
#
#    i.1
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4

# %%
df.shape
# Out:
# (1015, 9)

# %%
# To check null value 
(df.isna().sum() / len(df) * 100.00).hist()
# Out:
# <AxesSubplot:>

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# i                   539.000
# pro_rate_clean        0.600
# review_num_clean    922.000
# pro_price_clean     450.245
# i.1                 539.000
# dtype: float64

# %%
(df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))
# Out:
#           i    i.1  pro_name  pro_price  pro_price_clean  pro_rate  \
# 0     False  False     False      False            False     False
# 1     False  False     False      False            False     False
# 2     False  False     False      False            False     False
# 3     False  False     False      False            False     False
# 4     False  False     False      False            False     False
# ...     ...    ...       ...        ...              ...       ...
# 1143  False  False     False      False            False     False
# 1144  False  False     False      False            False     False
# 1145  False  False     False      False            False     False
# 1147  False  False     False      False            False     False
# 1148  False  False     False      False            False     False
#
#       pro_rate_clean  review_num  review_num_clean
# 0              False       False             False
# 1              False       False             False
# 2               True       False             False
# 3              False       False             False
# 4              False       False              True
# ...              ...         ...               ...
# 1143            True       False             False
# 1144           False       False             False
# 1145           False       False             False
# 1147            True       False             False
# 1148           False       False             False
#
# [1015 rows x 9 columns]

# %%
sns.boxplot(df['pro_rate_clean'])
# Out:
# <AxesSubplot:xlabel='pro_rate_clean'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='review_num_clean', data= df)
# Out:
# <AxesSubplot:xlabel='review_num_clean'>
